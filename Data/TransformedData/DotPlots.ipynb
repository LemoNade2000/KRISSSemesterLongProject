# %%
import pandas as pd
#import Numpy as np
import plotly.express as px
import matplotlib.pyplot as plt

# %%
stock_list=['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADM', 'AAP', 'AES', 'AFL', 'A', 'APD', 'ALK', 'ALB', 'ARE', 'ALLE', 'ALL', 'MO', 'AMCR', 'AEE', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'ABC', 'AME', 'APH', 'AON', 'APTV', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'AZO', 'AVB', 'AVY', 'BALL', 'BAC', 'BBWI', 'BAX', 'BDX', 'WRB', 'BRK-B', 'BBY', 'BIO', 'BLK', 'BK', 'BA', 'BWA', 'BXP', 'BSX', 'BMY', 'BR', 'BRO', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBRE', 'CE', 'CNC', 'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'C', 'CFG', 'CLX', 'CMS', 'KO', 'CL', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'COO', 'GLW', 'CTVA', 'CTRA', 'CCI', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'DVN', 'DLR', 'DFS', 'DIS', 'DG', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DD', 'DXC', 'EMN', 'ETN', 'ECL', 'EIX', 'EW', 'ELV', 'LLY', 'EMR', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQR', 'ESS', 'EL', 'RE', 'EVRG', 'ES', 'EXR', 'XOM', 'FDS', 'FRT', 'FDX', 'FRC', 'FE', 'FIS', 'FLT', 'FMC', 'F', 'FTV', 'FBHS', 'BEN', 'FCX', 'GRMN', 'IT', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GL', 'GPN', 'GS', 'HAL', 'HIG', 'HCA', 'PEAK', 'HSY', 'HES', 'HPE', 'HLT', 'HD', 'HRL', 'HWM', 'HPQ', 'HUM', 'HII', 'IBM', 'IEX', 'ITW', 'IR', 'ICE', 'IP', 'IPG', 'IFF', 'IVZ', 'INVH', 'IQV', 'IRM', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KR', 'LHX', 'LH', 'LW', 'LVS', 'LDOS', 'LEN', 'LNC', 'LIN', 'LYV', 'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MMC', 'MLM', 'MAS', 'MA', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'MET', 'MTD', 'MGM', 'MAA', 'MHK', 'MOH', 'TAP', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NEM', 'NEE', 'NKE', 'NI', 'NSC', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVR', 'OXY', 'OMC', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PKG', 'PH', 'PAYC', 'PNR', 'PKI', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'PPG', 'PPL', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PSA', 'PHM', 'PWR', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'RF', 'RSG', 'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'RCL', 'SPGI', 'CRM', 'SLB', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'STT', 'STE', 'SYK', 'SYF', 'SYY', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TXT', 'TMO', 'TJX', 'TT', 'TDG', 'TRV', 'TFC', 'TWTR', 'TYL', 'TSN', 'USB', 'UDR', 'UNP', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VZ', 'VFC', 'VICI', 'V', 'VNO', 'VMC', 'WAB', 'WMT', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WRK', 'WY', 'WHR', 'WMB', 'GWW', 'XYL', 'YUM', 'ZBH', 'ZTS']
csv_list = []
for i in range(len(stock_list)):
    csv_list.append(stock_list[i]+'.csv')
print(len(csv_list))

# %%
'''
for i in range(len(csv_list)):
    read = pd.read_csv(csv_list[i])
    xlist = read['id'].tolist()
    ylist=read['RecoveryDate'].tolist()
    df_list = []
    for m in range(len(xlist)):
        item=[]
        item.append(xlist[m])
        item.append(ylist[m])
        df_list.append(item)
    df = pd.DataFrame(df_list, columns = ['FOMC incidence','Recovery Date'])
    fig = px.scatter(df, x='FOMC incidence', y = 'Recovery Date', title = 'Recovery dates for '+csv_list[i][:-4], height = 500, width = 500)
    fig.show()
'''

# %%
for i in range(10):
    read = pd.read_csv(csv_list[i])
    xlist = read['id'].tolist()
    ylist=read['RecoveryDate'].tolist()
    fig, ax = plt.subplots()
    ax.scatter(xlist, ylist)
    ax.set_xlabel("FOMC incidents")
    ax.set_ylabel("Recovery Date")
    ax.title.set_text('Recovery dates for '+csv_list[i][:-4])
    fig.set_figwidth(15)
    ax.set_xticks(xlist)
    ax.set_xticklabels(xlist, rotation=90)
    plt.show()






'''
x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
sizes = np.random.rand(*x.shape) * 800 + 500

fig, ax = plt.subplots()
ax.scatter(x, y, sizes, c="green", alpha=0.5, marker=r'$\clubsuit$',
           label="Luck")
ax.set_xlabel("Leprechauns")
ax.set_ylabel("Gold")
ax.legend()
plt.show()
'''
# Out:
# '\nx = np.arange(0.0, 50.0, 2.0)\ny = x ** 1.3 + np.random.rand(*x.shape) * 30.0\nsizes = np.random.rand(*x.shape) * 800 + 500\n\nfig, ax = plt.subplots()\nax.scatter(x, y, sizes, c="green", alpha=0.5, marker=r\'$\\clubsuit$\',\n           label="Luck")\nax.set_xlabel("Leprechauns")\nax.set_ylabel("Gold")\nax.legend()\nplt.show()\n'
